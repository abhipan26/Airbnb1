# %% [markdown]
# # **Project Name**    - AirBnb Bookings Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - Abhishek pandey

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The name 'Airbnb' stands for 'Air Bed and Breakfast'.
#
# An Airbnb Exploratory Data Analysis (EDA) project involves analyzing a dataset related to Airbnb listings, bookings, or reviews to extract insights and patterns. The project typically includes steps such as data cleaning, exploration, and visualization to understand factors influencing pricing, popularity, and guest preferences. Key components may involve analyzing geographic distribution of listings, seasonal trends, correlation between listing attributes and prices, sentiment analysis of reviews, and identifying outliers or anomalies. The goal is to provide actionable insights to hosts, guests, or Airbnb itself for making informed decisions and improving the overall experience.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# "Given a dataset containing information about Airbnb listings, bookings, and reviews, the goal of this project is to perform comprehensive exploratory data analysis to gain insights into factors influencing listing popularity, pricing dynamics, and guest preferences. By analyzing various attributes such as location, property type, amenities, reviews, and pricing, we aim to uncover patterns and trends that can inform hosts in optimizing their listings, assist guests in making informed booking decisions, and provide valuable insights to Airbnb for enhancing their platform's user experience and business strategy."

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# In the context of this project, the business objective is to use data analysis to identify the characteristics of successful hosts, understanding the demand for listings in different locations, identifying new markets or demographics to target with marketing efforts and predicting factors such as pricing and demand.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Import warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb = pd.read_csv('/content/drive/MyDrive/dataset/Airbnb NYC 2019.csv')
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row_count, column_count = airbnb.shape
print("Number of rows:", row_count)
print("Number of columns:", column_count)
# Out:
# Number of rows: 48895
# Number of columns: 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
Total = airbnb.isnull().sum().sort_values(ascending = False)#total per column
missing_values= round(((airbnb.isnull().sum())*100)/airbnb.isnull().count().sort_values(ascending = False),2)
#missing_value data frame.
missing_total_percentage = pd.concat([Total,missing_values],axis = 1,keys = ['Total','Percentage'],sort = False).sort_values('Total',ascending=False)
missing_total_percentage
# Out:
#                                 Total  Percentage
# last_review                     10052       20.56
# reviews_per_month               10052       20.56
# host_name                          21        0.04
# name                               16        0.03
# id                                  0        0.00
# host_id                             0        0.00
# neighbourhood_group                 0        0.00
# neighbourhood                       0        0.00
# latitude                            0        0.00
# longitude                           0        0.00
# room_type                           0        0.00
# price                               0        0.00
# minimum_nights                      0        0.00
# number_of_reviews                   0        0.00
# calculated_host_listings_count      0        0.00
# availability_365                    0        0.00

# %% [markdown]
# ## Finding unique values in columns

# %%
# How many listings are there?
airbnb.id.nunique()
# Out:
# 48895

# %%
# How many neighborhoods are there?
airbnb.neighbourhood.nunique()
# Out:
# 221

# %%
# How many hosts are there?
airbnb.host_id.nunique()
# Out:
# 37457

# %%
# Neighborhood groups are there
airbnb.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
# Room types are available for rental
airbnb.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1.The dataset has 16 columns and 48,895 rows.
# 2.A significant number of values seem to be missing from the last_review and reviews_per_month columns.
# 3.The rows are entirely unique meaning there is no repeated record.
# 4.There are five different neighborhood groups, 221 neighborhoods, 37,457 hosts, 48,895 listings, and three types of room available for rental.
#
# ```
#
# ```

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb.describe().round(2)
# Out:
#                 id       host_id  latitude  longitude     price  \
# count     48895.00  4.889500e+04  48895.00   48895.00  48895.00
# mean   19017143.24  6.762001e+07     40.73     -73.95    152.72
# std    10983108.39  7.861097e+07      0.05       0.05    240.15
# min        2539.00  2.438000e+03     40.50     -74.24      0.00
# 25%     9471945.00  7.822033e+06     40.69     -73.98     69.00
# 50%    19677284.00  3.079382e+07     40.72     -73.96    106.00
# 75%    29152178.50  1.074344e+08     40.76     -73.94    175.00
# max    36487245.00  2.743213e+08     40.91     -73.71  10000.00
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count        48895.00           48895.00           38843.00
# mean             7.03              23.27               1.37
# std             20.51              44.55               1.68
# min              1.00               0.00               0.01
# 25%              1.00               1.00               0.19
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id : Unique Id generated while storing data
#
# name : Name of the listing
#
# host_id : The host id is assigned to each host by Airbnb and is used to identify and distinguish hosts from one another.
#
# host_name : The host name is typically the name of the person who owns the property or is authorized to list it on Airbnb.
#
# neighbourhood_group : Location of the listing / categorical variable that indicates the general geographic area in which a listing is located.
#
# neighbourhood : area of the listing
#
# latitude : Latitude range of the listing
#
# longitude : Longitude range of the listing
#
# room_type : Type of the listing
#
# price : Price of the listing
#
# minimum_nights : Minimum nights to be paid for
#
# number_of_reviews : Number of reviews for the listing
#
# last_review : Content of the last review
#
# reviews_per_month : Average number of reviews that a listing receives per month
#
# calculated_host_listings_count : Total number of listings that a host has on the Airbnb platform
#
# availability_365 : The number of days in a year that a listing is available for booking on the Airbnb platform based on the listing's calendar, and reflects the number of days in the future that the listing is marked as available for booking.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in airbnb.columns.tolist():
  print("No. of unique values in",i,"is",airbnb[i].nunique())
# Out:
# No. of unique values in id is 48895
# No. of unique values in name is 47905
# No. of unique values in host_id is 37457
# No. of unique values in host_name is 11452
# No. of unique values in neighbourhood_group is 5
# No. of unique values in neighbourhood is 221
# No. of unique values in latitude is 19048
# No. of unique values in longitude is 14718
# No. of unique values in room_type is 3
# No. of unique values in price is 674
# No. of unique values in minimum_nights is 109
# No. of unique values in number_of_reviews is 394
# No. of unique values in last_review is 1764
# No. of unique values in reviews_per_month is 937
# No. of unique values in calculated_host_listings_count is 47
# No. of unique values in availability_365 is 366

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Befor doing any data wrangling lets create copy of data set
df2 = airbnb.copy()

# %%
# Checking the number of rows with zero price values in our dataset.
df2[df2.price==0].shape
# Out:
# (11, 16)

# %%
# Removing rows having zero price values from our dataset.
df2 = df2[df2['price'] !=0]

# %%
# Since both 'name' and 'host_name' has very less missing values as compared to the
# Entire dataset we can fill these missing values in both with unknown & no_name respectively!

df2['name'].fillna('unknown',inplace=True)
df2['host_name'].fillna('anonymous',inplace=True)

# %%
# Checks if any null values still exist!
df2[['host_name','name']].isnull().values.any()
# Out:
# False

# %%
# Filling null values in reviews_per_month column with 0
df2['reviews_per_month'] = airbnb['reviews_per_month'].fillna(0)

# %%
# Drop the last_review column
df2.drop(['last_review'], axis=1, inplace=True)

# %%
# Checking change in shape
df2.shape
# Out:
# (48884, 15)

# %% [markdown]
# Previous shape was (48895, 16) and the shape of the new data frame created after cleaning is (48884, 15) Hence correctly removed 11 rows where the price value was 0

# %%
# Checking the changes
df2.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# # Handling the outliers

# %% [markdown]
# Outliers in the price column

# %%
# Boxplot of 'price' column
sns.boxplot(df2['price'])
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# Removing Outliers using IQR approach! (has performed best in removing outliers)

# %%
# Calculate the IQR and boundaries
Q1 = df2['price'].quantile(0.25)
Q3 = df2['price'].quantile(0.75)
IQR = Q3 - Q1
lower_boundary = Q1 - 1.5 * IQR
upper_boundary = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df2 = df2[(df2['price'] >= lower_boundary) & (df2['price'] <= upper_boundary)]

# %%
#the boxplot for price now looks good without outliers!
sns.boxplot(df2['price'])
# Out:
# <Axes: ylabel='price'>

# %%
# Distribution Plot of 'price' column
sns.distplot(df2['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# Outliers in the minimum nights column

# %%
# Calculate the IQR and boundaries
Q1 = df2['minimum_nights'].quantile(0.25)
Q3 = df2['minimum_nights'].quantile(0.75)
IQR = Q3 - Q1
lower_boundary = Q1 - 1.5 * IQR
upper_boundary = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df2 = df2[(df2['minimum_nights'] >= lower_boundary) & (df2['minimum_nights'] <= upper_boundary)]

# %%
# Boxplot of 'minimum_nights' column without outliers
sns.boxplot(df2['minimum_nights'])
# Out:
# <Axes: ylabel='minimum_nights'>

# %%
# Distribution plot of 'minimum_nights' column
sns.distplot(df2['minimum_nights'])
# Out:
# <Axes: xlabel='minimum_nights', ylabel='Density'>

# %% [markdown]
# Finding Some Insights

# %%
#Lets check the statistical value(mean, median) of all feature of neighbourbood group wise

df_mean_median = df2[['neighbourhood_group','price','minimum_nights','number_of_reviews','availability_365']]
#defining a function get_mean_median_mode to fing mean and median
def get_mean_median(data,neighbourhood_group):
  ''' This fuction gives mean and median of all features'''
  # try block to utilize eror handling
  try:
    return pd.concat([df_mean_median[df_mean_median['neighbourhood_group']==neighbourhood_group].describe().round(2).iloc[1],
          df_mean_median[df_mean_median['neighbourhood_group']==neighbourhood_group].describe().round(2).iloc[5]], axis = 1).rename(columns={'50%':'Median'})
  # except block to catch error
  except:
    print("Invalid Neighbourhood Group")

# %%
# using a for loop to print the mean and median for all unique values from the neighborhood group
for i in airbnb.neighbourhood_group.unique():
  print(i,get_mean_median(df_mean_median,i))
  print('\n')
# Out:
# Brooklyn                      mean  Median
# price              107.09    90.0
# minimum_nights       2.81     2.0
# number_of_reviews   26.19     7.0
# availability_365    91.62    18.0
#
#
# Manhattan                      mean  Median
# price              143.94   130.0
# minimum_nights       2.74     2.0
# number_of_reviews   25.19     6.0
# availability_365    83.07     8.0
#
#
# Queens                      mean  Median
# price               91.11    75.0
# minimum_nights       2.28     2.0
# number_of_reviews   30.11     9.0
# availability_365   141.24    90.0
#
#
# Staten Island                      mean  Median
# price               89.52    75.0
# minimum_nights       2.37     2.0
# number_of_reviews   32.92    15.5
# availability_365   198.72   217.5
#
#
# Bronx                      mean  Median
# price               78.15    65.0
# minimum_nights       2.25     2.0
# number_of_reviews   27.47     9.0
# availability_365   162.06   140.0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Manipulations**

# %% [markdown]
# 1.We have copied the dataframe so that we have a copy of the data just in case we mess up somewhere
#
# 2.Next we checked for listings which had price = 0$ which makes no sense
#
# 3.After that we replaced the null values in the 'name', 'host_name' & 'reviews_per_month' columns and dropped the 'last_reviews' column.
#
# 4.At this stage we checked the null values and it was all fixed with a dataframe shape(48884, 15)
#
# 5.After this we handled the outliers using the IQR Approach as we could see in the box plot that we had a bunch of outliers in the 'price' and 'minimum_nights' columns

# %% [markdown]
# **Insights**
#
# 1.We found out the mean and median for all values for a particular neighbourhood group
#
# 2.We can see that the mean and medial for the price column usually tends to be around the same range

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# Chart - 1 Distribution of column by Using Histogram and box plot

# %%
# Chart - 1 visualization code

for col in df2.describe().columns:
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

    # Histogram plot
    sns.histplot(df2[col], ax=axes[0], kde=True, color='#05204a', edgecolor='white')
    axes[0].set_xlabel(col)
    axes[0].set_ylabel('Frequency')
    axes[0].set_title("Distribution of " + col, fontsize=15)
    axes[0].grid(True, linestyle='--')

    # Boxplot
    sns.boxplot(df2[col], ax=axes[1], orient='h', showmeans=True, color='#cafe48')
    axes[1].set_xlabel(col)
    axes[1].set_ylabel('')
    axes[1].set_title("Boxplot of " + col, fontsize=15)
    axes[1].grid(True, linestyle='--')

    # Adjust spacing between subplots
    plt.tight_layout()

    # Show the plots
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram plot to analyse the variable distributions over the whole dataset whether it's symmetric or not.
#
# Box plot to analyse the outliers and interquartile range including median, maximum and minimum value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above distribution charts we can see that, not all columns are symmetrically distributed and the mean and median are ranging the same is for numerical columns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# What is the average price for each neighbourhood group?

# %%
# Group the dataset by "Neighbourhood group" and calculate the average price
neighborhood_avg_price = df2.groupby('neighbourhood_group')['price'].mean()

# Set the style of the plot
sns.set(style="whitegrid")

# Create a bar plot with custom color palette
plt.figure(figsize=(10, 6))
colors = ['#272932', '#f05d5e', '#0f7173', '#9fc2cc', '#dbc648']
ax = sns.barplot(x=neighborhood_avg_price.index, y=neighborhood_avg_price, palette=colors)

# Set the title and axis labels
plt.title('Neighbourhood Group vs. Average Price', fontsize=16)
plt.xlabel('Neighbourhood Group', fontsize=12)
plt.ylabel('Average Price', fontsize=12)
plt.xticks(rotation=30)

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 5), textcoords='offset points', fontsize=10)

# Remove the top and right spines
sns.despine()

#display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is an effective visualization technique for comparing the average prices of different neighborhood groups in the Airbnb 2019 NYC data set.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By analyzing the bar plot we can clearly observe that the average price of manhattan is maximum i.e 143.94
# On the second position we have Brooklyn for $107.09 avg price and the average price is minimum in bronx i.e 78.15

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Airbnb can leverage this insight to develop targeted pricing strategies for different regions.
#
# Understanding regional price variations allows Airbnb to tailor marketing campaigns and promotional offers to different customer segments

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# Which neighbourhood group has the highest number of listings?

# %%
# Chart - 3 visualization code
#using a pivot plot
df2_pivot = pd.pivot_table(df2, index=['neighbourhood_group'], values='id', aggfunc=['count'], margins=True, margins_name='Total Count')
df2_pivot
# Out:
#                      count
#                         id
# neighbourhood_group
# Bronx                 1009
# Brooklyn             17341
# Manhattan            16008
# Queens                5027
# Staten Island          344
# Total Count          39729

# %% [markdown]
# By creating a pivot table of the total number of listings grouped by the different group, we learn that out of the 39729 listings being analyzed, 17341 of them are located in Brooklyn and 16008 in Manhattan. Staten Island shows up last with only 344 listings.
#
# We can use a pie chart to better visualize how the numbers are distributed in percentages:

# %%
df3 = df2.groupby('neighbourhood_group')['id'].count()

plt.figure(figsize=(10, 8))
colors = ['#272932', '#f05d5e', '#0f7173', '#9fc2cc', '#dbc648']

explode = (0, 0, 0.1, 0, 0)  # Explode the first slice for emphasis

sns.set(style='whitegrid')
sns.set_palette(sns.color_palette(colors))

df3.plot.pie(labels=df3.index, autopct='%1.0f%%', startangle=0, explode=explode,
             wedgeprops=dict(width=0.3), shadow=True)

plt.ylabel('Neighbourhood Group', fontsize=12)
plt.title('Total Listings by Neighbourhood Group', fontsize=16)

plt.axis('equal')  # Equal aspect ratio ensures a circular pie

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie plot is a suitable visualization for determining the neighborhood group with the highest percentage of listings in the Airbnb 2019 NYC dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan and Brooklyn have the highest number of listings on Airbnb with manhattan with 41% and Brooklyn with 44%
#
# Queens and the Bronx have significantly fewer listings compared to Manhattan and Brooklyn, with 13% and 3% listings, respectively
#
# Staten Island has the fewest number of listings, with only 1%.
#
# The distribution of listings across the different neighborhood groups is skewed, with a concentration of listings in Manhattan and Brooklyn.
#
# Despite being larger in size, the neighborhoods in Queens, the Bronx, and Staten Island have fewer listings on Airbnb compared to Manhattan, which has a smaller geographical area.
#
# .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This could suggest that the demand for Airbnb rentals is higher in Brooklyn compared to the other neighborhoods, leading to a higher concentration of listings in this area.
#
# Alternatively, it could be that the supply of listings is higher in Manhattan due to a higher number of homeowners or property owners in this neighborhood who are willing to list their properties on Airbnb

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# Price Distribution Of Each Neighbourhood Group using Violin Plot

# %%
# Chart - 4 visualization code
# Create the violin plot for price distribution in each Neighbourhood_groups

ax= sns.violinplot(x='neighbourhood_group',y='price',data= df2)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By utilizing a violin plot, analysts can gain insights into how the prices vary across different neighbourhood_group in the Airbnb.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Price distribution is very high in Manhattan and Brooklyn. But Manhattan have more Diversity in price range, you can see in violin plot.
#
# Queens and Bronx have same price distribution but in Queens area more distribution in 50
#  but diversity in price is not like Manhattan and Brooklyn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# What is the average price of Airbnb listings in NYC in 2019 by room type?

# %%
# Chart - 5 visualization code
# Select the relevant columns
df = df2[['neighbourhood_group', 'room_type', 'price']]

# Group the data by neighbourhood_group and room_type, and calculate the mean price
df = df.groupby(['neighbourhood_group', 'room_type'], as_index=False)[['price']].mean()

# Create a figure and set the theme to white
plt.figure(figsize=(12, 6))
sns.set_theme(style='white')

# creating palette
my_pal = {'Entire home/apt': '#f05f5e', 'Private room': '#ead94c', 'Shared room': '#0f7173'}

# Create a bar plot with x as neighbourhood_group, y as price, hue as room_type, and using the custom color palette
df = sns.barplot(x="neighbourhood_group", y="price", data=df, hue='room_type', palette=my_pal)

# Add annotations to the bars with the formatted average price values
for p in df.patches:
    df.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', size=11, xytext=(0, -12), textcoords='offset points')

# Set the x and y labels, and the title of the plot
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price')
plt.title('Average Price by Room Type')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is used in the Airbnb 2019 NYC dataset to visualize the distribution of listing prices across different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Guests can quickly identify the price brackets associated with each room type, helping them narrow down their search and find accommodations that fit their budget.
# In a bar chart we can clearly see that average price of all room type is maximum in Manhattan.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The bar plot provides valuable insights into the distribution of listing prices across different room types. Hosts can analyze the price ranges for each room type and adjust their pricing strategies accordingly. By understanding the pricing patterns, hosts can optimize their prices to attract guests while maximizing their profitability.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# Average Price Of Each Neighborhood Group using Point Plot

# %%
# Chart - 6 visualization code

# Group the Airbnb dataset by neighborhood group and calculate the mean of each group
grouped = df2.groupby("neighbourhood_group").mean()

# Reset the index of the grouped dataframe so that the neighborhood group becomes a column
neighbourhood_group_avg_price = grouped.reset_index()

# Rename the "price" column to "avg_price"
neighbourhood_group_avg_price = round(neighbourhood_group_avg_price.rename(columns={"price": "avg_price"}),2)

# Select only the "neighbourhood_group" and "avg_price" columns
neighbourhood_group_avg_price[['neighbourhood_group', 'avg_price']].head()
# Out:
#   neighbourhood_group  avg_price
# 0               Bronx      78.15
# 1            Brooklyn     107.09
# 2           Manhattan     143.94
# 3              Queens      91.11
# 4       Staten Island      89.52

# %%
#import mean function from the statistics module
from statistics import mean

# Create the point plot
sns.pointplot(x = 'neighbourhood_group', y='price', data=df2, estimator = np.mean)

# Add axis labels and a title
plt.xlabel('Neighbourhood Group',fontsize=14)
plt.ylabel('Average Price',fontsize=14)
plt.title('Average Price by Neighbourhood Group',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Average Price by Neighbourhood Group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By using a line plot, analysts can gain insights into how the average price of neighbourhood group increases or decreases.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The average price of a listing in New York City varies significantly across different neighborhoods, with Manhattan having the highest 144 dollars/day average price and the Bronx having the lowest near 78 dollars/day.
#
# The average price in queens and Staten Island is relatively similar, despite being in different parts of the city.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The data suggests that the overall cost of living in New York City is higher in the center of the city (Manhattan) compared to the outer boroughs. This is likely due to the fact that Manhattan is the most densely populated and commercially important borough, and therefore has higher demand for housing in the centrally located neighborhoods

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# Top Hosts With More Listing/Property using Bar chart

# %%
# Chart - 7 visualization code

# create a new DataFrame that displays the top 10 hosts in the Airbnb NYC dataset based on the number of listings each host has
top_10_hosts = df2['host_name'].value_counts()[:10].reset_index()

# rename the columns of the resulting DataFrame to 'host_name' and 'Total_listings'
top_10_hosts.columns = ['host_name', 'Total_listings']

# display the resulting DataFrame
top_10_hosts
# Out:
#   host_name  Total_listings
# 0   Michael             326
# 1     David             319
# 2      John             237
# 3      Alex             219
# 4     Sarah             211
# 5    Daniel             189
# 6     Maria             179
# 7   Jessica             169
# 8    Andrew             162
# 9      Anna             158

# %%
# Get the top 10 hosts by listing count
top_hosts = df2['host_name'].value_counts()[:10]

# Create a bar plot of the top 10 hosts
top_hosts.plot(kind='bar', color='peru', figsize=(18, 7))

# Set the x-axis label
plt.xlabel('top10_hosts', fontsize=14)

# Set the y-axis label
plt.ylabel('total_NYC_listings', fontsize=14)

# Set the title of the plot
plt.title('top 10 hosts on the basis of no of listings in entire NYC!', fontsize=15)
# Out:
# Text(0.5, 1.0, 'top 10 hosts on the basis of no of listings in entire NYC!')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart is used to do a comparison among the host with maximum listing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The top three hosts in terms of total listings are Michael, David, and John, who have 326, 319, and 237 listings, respectively.
#
# There is a relatively large gap between the top two hosts and the rest of the hosts. For example, john has 237 listings, which is significantly fewer than Michael's 319 listings.
#
# In this top10 list Anna has 158 listings, which is significantly fewer than Michael's 326 listings. This could indicate that there is a lot of variation in the success of different hosts on Airbnb.
#
# There are relatively few hosts with a large number of listings. This could indicate that the Airbnb market is relatively competitive, with a small number of hosts dominating a large portion of the market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# What is the average price by room type?

# %%
# Chart - 8 visualization code
room_type_avg_price = df2.groupby('room_type')['price'].mean().reset_index()

# Set the style and color palette
sns.set(style='whitegrid')
pal=['#f05d5e','#dbc648','#9fc2cc']

# Create a bar plot to visualize the average price by room type
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='room_type', y='price', data=room_type_avg_price, palette = pal)

# Add labels to the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', size=11, xytext=(0, -12), textcoords='offset points')

# Set the title and axis labels
plt.title('Average Price by Room Type', fontsize=16)
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Average Price', fontsize=12)

# Remove the top and right spines
sns.despine()

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By utilizing a bar plot, analysts can gain insights into the average prices associated with different room types in the Airbnb 2019 NYC dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot displaying the average prices by room types in the Airbnb 2019 NYC dataset provides valuable insights.
# From the bar we clearly see that the average price of entire home/apt is maximum whereas the shared room type has minimum average price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from analyzing the average prices by room types in the Airbnb 2019 NYC dataset have the potential to create a positive business impact.
# Hosts can optimize their pricing strategies based on the observed average prices, aiming for a competitive position in the market.
# Understanding the average prices by room types helps hosts make informed decisions to attract more guests and increase bookings.
# However, there is a risk of negative growth if certain room types are consistently overpriced, as it may deter potential guests and decrease demand.
# Hosts should strike a balance between competitiveness and profitability, considering market dynamics and guest preferences.
# It is essential to regularly monitor and adjust prices to ensure sustainable business growth and maintain a competitive edge in the market.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# What is the number of reviews for Airbnb listings in NYC in 2019 by room type?

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10, 6))

# Set seaborn theme to whitegrid
sns.set_theme(style="whitegrid")


# Custom color palette
colors = ['#f05d5e','#0f7173','#dbc648']

# Create the bar plot
ax = sns.barplot(x="room_type", y="number_of_reviews", data=df2, palette=colors)

# Set the title and axis labels
plt.title('Number of Reviews by Room Type', fontsize=16)
plt.xlabel('Room Type', fontsize=12)
plt.ylabel('Number of Reviews', fontsize=12)

# Remove the top and right spines
sns.despine()

# Adjust the plot layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By utilizing a bar plot, analysts can gain insights into the number of reviews received by different room types in the Airbnb.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In a bar chart we can easily analyze that the number of reviews of private room is maximum and shared room reviews are minimum.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# As i compared the reviews and price from above two chart it clearly shows that the private room has less price than entire room that is why number is reviews is maximum for private room.
# This shows that the price of room matters to the people.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# Number Of Active Hosts Per Location Using Line Chart

# %%
# Chart - 10 visualization code

# create a new DataFrame that displays the number of hosts in each neighborhood group in the Airbnb NYC dataset
hosts_per_location = df2.groupby('neighbourhood_group')['calculated_host_listings_count'].count().reset_index()

# rename the columns of the resulting DataFrame to 'Neighbourhood_Groups' and 'Host_counts'
hosts_per_location.columns = ['Neighbourhood_Groups', 'Host_counts']

# display the resulting DataFrame
hosts_per_location
# Out:
#   Neighbourhood_Groups  Host_counts
# 0                Bronx         1091
# 1             Brooklyn        20104
# 2            Manhattan        21661
# 3               Queens         5666
# 4        Staten Island          373

# %%
# Group the data by neighbourhood_group and count the number of listings for each group
hosts_per_location = df2.groupby('neighbourhood_group')['calculated_host_listings_count'].count()

# Get the list of neighbourhood_group names
locations = hosts_per_location.index

# Get the list of host counts for each neighbourhood_group
host_counts = hosts_per_location.values

# Set the figure size
plt.figure(figsize=(12, 5))

# Create the line chart with some experiments using marker function
plt.plot(locations, host_counts, marker='o', ms=12, mew=4, mec='r')

# Add a title and labels to the x-axis and y-axis
plt.title('Number of Active Hosts per Location', fontsize='15')
plt.xlabel('Location', fontsize='14')
plt.ylabel('Number of Active Hosts', fontsize='14')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line chart is used to show the trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan has the largest number of hosts with 21661,Brooklyn has the second largest number of hosts with 20104.
#
# After that Queens with 5666 and the Bronx with 1091. while Staten Island has the fewest with 373.
#
# Brooklyn and Manhattan have the largest number of hosts..

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# Most reviewed room type per month in neighbourhood groups

# %%
# Chart - 11 visualization code
# create a figure with a default size of (10, 8)
f, ax = plt.subplots(figsize=(10, 8))

# create a stripplot that displays the number of reviews per month for each room type in the Airbnb NYC dataset
ax = sns.stripplot(x='room_type', y='reviews_per_month', hue='neighbourhood_group', dodge=True, data=df2, palette='Set1')

# set the title of the plot
ax.set_title('Most Reviewed room_types in each Neighbourhood Groups', fontsize='14')
# Out:
# Text(0.5, 1.0, 'Most Reviewed room_types in each Neighbourhood Groups')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By utilizing a strip plot, analysts can gain insights into the most reviewed room types in each neighborhood per month in the Airbnb 2019 NYC dataset. This visualization helps hosts understand which room types are in high demand and can guide their marketing and investment decisions. It also provides valuable information for guests seeking popular accommodations in specific neighborhoods and time periods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that Private room recieved the most no of reviews/month where Manhattan had the highest reviews received for Private rooms with more than 50 reviews/month, followed by Manhattan in the chase.
#
# Manhattan & Queens got the most no of reviews for Entire home/apt room type.
#
# There were less reviews recieved from shared rooms as compared to other room types and it was from Staten Island followed by Bronx.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Travellers are preffering private room mostly in Manhattan thats is why the client should work on this to get maximum benefits.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# Average Minimum Price In Neighborhoods using Scatter and Bar chart

# %%
# Chart - 12 visualization code

# create a new DataFrame that displays the average price of Airbnb rentals in each neighborhood
neighbourhood_avg_price = df2.groupby("neighbourhood").mean().reset_index().rename(columns={"price": "avg_price"})[['neighbourhood', 'avg_price']]

# select the top 10 neighborhoods with the lowest average prices
neighbourhood_avg_price = neighbourhood_avg_price.sort_values("avg_price").head(10)

# join the resulting DataFrame with the 'neighbourhood_group' column from the Airbnb NYC dataset, dropping any duplicate entries
neighbourhood_avg_price_sorted_with_group = neighbourhood_avg_price.join(df2[['neighbourhood', 'neighbourhood_group']].drop_duplicates().set_index('neighbourhood'),
                                                                         on='neighbourhood')

# Display the resulting data
display(neighbourhood_avg_price_sorted_with_group.style.hide_index())
# Out:
# <style type="text/css">
# </style>
# <table id="T_03a6f" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_03a6f_level0_col0" class="col_heading level0 col0" >neighbourhood</th>
#       <th id="T_03a6f_level0_col1" class="col_heading level0 col1" >avg_price</th>
#       <th id="T_03a6f_level0_col2" class="col_heading level0 col2" >neighbourhood_group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03a6f_row0_col0" class="data row0 col0" >Bull's Head</td>
#       <td id="T_03a6f_row0_col1" class="data row0 col1" >47.333333</td>
#       <td id="T_03a6f_row0_col2" class="data row0 col2" >Staten Island</td>
#     </tr>
#     <tr>
#       <td id="T_03a6f_row1_col0" class="data row1 col0" >Hunts Point</td>
#       <td id="T_03a6f_row1_col1" class="data row1 col1" >50.500000</td>
#       <td id="T_03a6f_row1_col2" class="data row1 col2" >Bronx</td>
#     </tr>
#     <tr>
#       <td id="T_03a6f_row2_col0" class="data row2 col0" >Tremont</td>
# ...

# %%
neighbourhood_avg_price = (df2.groupby("neighbourhood").mean().reset_index().rename(columns={"price": "avg_price"}))[['neighbourhood', 'avg_price']]
neighbourhood_avg_price = (neighbourhood_avg_price.sort_values("avg_price"))

# Group the data by neighborhood and calculate the average price
neighbourhood_avg_price = df2.groupby("neighbourhood")["price"].mean()

# Create a new DataFrame with the average price for each neighborhood
neighbourhood_prices = pd.DataFrame({"neighbourhood": neighbourhood_avg_price.index, "avg_price": neighbourhood_avg_price.values})

# Merge the average price data with the original DataFrame#trying to find where the coordinates belong from the latitude and longitude
df = df2.merge(neighbourhood_prices, on="neighbourhood")

# Create the scattermapbox plot
fig = df.plot.scatter(x="longitude", y="latitude", c="avg_price", title="Average Airbnb Price by Neighborhoods in New York City", figsize=(12,6), cmap="plasma")
fig
# Out:
# <Axes: title={'center': 'Average Airbnb Price by Neighborhoods in New York City'}, xlabel='longitude', ylabel='latitude'>

# %%
# Extract the values from the dataset
neighborhoods = neighbourhood_avg_price_sorted_with_group['neighbourhood']
prices = neighbourhood_avg_price_sorted_with_group['avg_price']

# Create the bar plot
plt.figure(figsize=(15,5))
plt.bar(neighborhoods, prices,width=0.5, color = 'orchid')
plt.xlabel('Neighborhood')
plt.ylabel('Average Price')
plt.title('Average Price by Neighborhood')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart is used to compare different variable like minimum nights and count

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All of the neighborhoods listed are located in the outer boroughs of New York City (Bronx, Queens, and Staten Island). This suggests that these neighborhoods may have a lower overall cost of living compared to neighborhoods in Manhattan and Brooklyn.
#
# Most of these neighborhoods are located in the Bronx and Staten Island. These boroughs tend to have a lower overall cost of living compared to Manhattan and Brooklyn.
#
# These neighborhoods may be attractive to renters or buyers looking for more affordable housing options in the New York City

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# > #### Chart - 13

# %% [markdown]
# Use latitude and longitude in scatterplot map and find neighbourhood_groups and Room types in map

# %%
# Chart - 13 visualization code

#trying to find where the coordinates belong from the latitude and longitude

# set the default figure size for the seaborn library
sns.set(rc={"figure.figsize": (10, 8)})

# create a scatter plot that displays the longitude and latitude of the listings in the Airbnb NYC dataset
ax = sns.scatterplot(data=df2, x="longitude", y="latitude", hue='neighbourhood_group', palette='bright')

# set the title of the plot
ax.set_title('Location Co-ordinates', fontsize='14')
# Out:
# Text(0.5, 1.0, 'Location Co-ordinates')

# %%
# Let's observe the type of room_types

# set the default figure size for the seaborn library
sns.set(rc={"figure.figsize": (10, 8)})

# create a scatter plot that displays the longitude and latitude of the listings in the Airbnb NYC dataset with room_types.
ax = sns.scatterplot(x=df2.longitude, y=df2.latitude, hue=df2.room_type, palette='muted')

# set the title of the plot
ax.set_title('Distribution of type of rooms across NYC', fontsize='14')
# Out:
# Text(0.5, 1.0, 'Distribution of type of rooms across NYC')

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Define a custom color palette
custom_colors = ['#dbc648', '#9fc2cc','#0f7173','#f05d5e', '#272932']

# Defining the correlation function
plt.figure(figsize=(12, 6))
corr = df2.corr()

# Visualize correlations as a heatmap with the custom color palette
sns.heatmap(corr, cmap=custom_colors, annot=True)

# Display the heatmap
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen because it provides a comprehensive overview of the relationships between variables in the dataset. It allows for easy identification of patterns and associations between different features, helping to uncover potential insights and understand the underlying structure of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a moderate positive correlation (0.59) between the host_id and id columns, which suggests that hosts with more listings are more likely to have unique host IDs.
#
# There is a weak positive correlation (0.057) between the price column and the calculated_host_listings_count column, which suggests that hosts with more listings tend to charge higher prices for their listings.
#
# There is a moderate positive correlation (0.23) between the calculated_host_listings_count column and the availability_365 column, which suggests that hosts with more listings tend to have more days of availability in the next 365 days.
#
# There is a strong positive correlation (0.58) between the number_of_reviews column and the reviews_per_month column, which suggests that listings with more total reviews tend to have more reviews per month.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Create a pairplot using the seaborn library to visualize the relationships between different variables in the Airbnb NYC dataset
sns.pairplot(df2)

# Show the plot
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot consists of multiple scatterplots arranged in a grid, with each scatterplot showing the relationship between two variables
#
# It can be used to visualize relationships between multiple variables and to identify patterns in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Based on the analysis, it is clear that
#
# There are host which take minimum booking for entire year and not even available for booking but has high booking price, these listing should be either removed or should undergo physical verification to learn exact reason.
#
# In order to increase profit for host with less lisitng, special promotional offer should be given and personalised marketing for them should be done from airbnb to promote business in their specific region.
#
# Price point for few area are relatively high compared to others based on number of listing in the other area, it could be changed.
#
# Reward for host who provide maximum customer engagement to keep them motivated, this will help in host retention and generation of profit.
#
# Since private room get maximum reviews per month, therefore, these kind of listing could be increased based on customer demand.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# From the above analysis, we could conclude that:
#
# Average price distribution for airbnb falls under the range of 150-200.
#
# Amoung all different area Manhattan and Brooklyn has maximum airbnb and Staten Island has least airbnb.
#
# Micheal is the most popular host with the highest number of airbnb listings.
#
# Price which airbnb offer in Manhattan is more than others.
#
# Maximum listing is in Brooklyn.
#
# Entire home/apt has maximum average price in all neighbourhood group.
#
# Private room got maximum number of reviews.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
